# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df_drunk = pd.read_csv('/kaggle/input/final-results/D_modeljustCSAfinal.csv')
df_drunk.head()

# %%
# histogram plot
from numpy.random import seed
from numpy.random import randn
from matplotlib import pyplot

pyplot.hist(df_drunk['mae'],20)
pyplot.show()

# %%
df_normal = pd.read_csv('../input/final-results/N_modeljustCSAfinal.csv')
df_normal.head()

# %%
from numpy.random import seed
from numpy.random import randn
from matplotlib import pyplot

pyplot.hist([df_normal['loss'],df_drunk['loss']],25)
pyplot.xlabel('Loss')
pyplot.ylabel('Frequency')
pyplot.axvline(x=0.0320, linewidth=2, color='g', label="Mean", linestyle = '--', alpha=0.9)
pyplot.legend(['Threshold','Normal', 'Drunk'])
pyplot.show()

# %%
pyplot.hist([df_normal['mae'],df_drunk['mae']],25)
pyplot.xlabel('Mean Absolute Error')
pyplot.ylabel('Frequency')
pyplot.axvline(x=0.135, linewidth=2, color='g', label="Mean", linestyle = '--', alpha=0.9)
pyplot.legend(['Threshold','Normal', 'Drunk'])
pyplot.show()

# %%
pyplot.hist(df_normal['loss'],100)
pyplot.show()

# %%
df_normal = pd.read_csv('../input/results/normal_video_withmodel4.csv')
df_normal.head()

# %%
df_normal.count()

# %%
df_drunk.count()

# %%
df = df_normal.drop([12,25])

# %%
pyplot.hist(df['mae'],30)
pyplot.show()

# %%
import matplotlib.pyplot as plt
colors = ['red', 'blue']
label = ['drunk','normal']
pyplot.hist([df_drunk['mae'],df['mae']],30,color = colors,label = label)
pyplot.show()

# %%
import matplotlib.pyplot as plt
colors = ['red', 'blue']
#label = ['drunk','normal']
pyplot.hist([result['mae'],df['mae']],20,color = colors,label=label)
pyplot.show()

# %%
from numpy.random import seed
from numpy.random import randn
from matplotlib import pyplot

pyplot.hist(df_Hdrunk['mae'],25)
pyplot.show()

# %%
df_hdrunk = pd.read_csv('../input/results/highlydrunk_video_withmodel4.csv')
df_hdrunk.head()

# %%
pyplot.hist(df_hdrunk['mae'],25)
pyplot.show()

# %%
frames = [df_drunk, df_hdrunk]
result = pd.concat(frames)

# %%
result

# %%
import matplotlib.pyplot as plt
colors = ['red', 'blue']
#label = ['drunk','normal']
pyplot.hist([result['cosin'],df['cosin']],30,color = colors,label=label)
pyplot.show()

# %%
df_hdrunk['mae']

# %%
A =df_hdrunk[df_hdrunk['mae'] >= 0.1015]
A

# %%
A =df_drunk[df_drunk.mae > 0.135].count()
a= A['loss']
b = df_drunk['loss'].count()
print(a/b)

B =df_normal[df_normal.mae > 0.135].count()
c = B['loss']
d = df_normal['loss'].count()
print(c/d)
#drunck.count()
#drunck.to_numpy()
#drunck

# %%
A =df_drunk[df_drunk.loss > 0.0275].count()
a= A['loss']
b = df_drunk['loss'].count()
print(a/b)

B =df_normal[df_normal.loss > 0.0275].count()
c = B['loss']
d = df_normal['loss'].count()
print(c/d)

# %%
df_drunk.loss > 0.0136

# %%
#A = df_drunk[df_drunk.loss > 0.0136]
df_drunk['classify'] = df_drunk.mae > 0.136
df_drunk['GT'] = 1
df_drunk

# %%
df_drunk['classify']  = df_drunk['classify'].replace([False],0)
df_drunk['classify']  = df_drunk['classify'].replace([True],1)
df_drunk

# %%
df_normal['classify'] = df_normal.mae > 0.136
df_normal['GT'] = 0
df_normal

# %%
df_normal['classify']  = df_normal['classify'].replace([False],0)
df_normal['classify']  = df_normal['classify'].replace([True],1)
df_normal

# %%
frames = [df_normal, df_drunk]
result = pd.concat(frames)
result

# %%
result['GT']

# %%
result['classify'].to_numpy()

# %%
from sklearn.metrics import confusion_matrix

# %%
cf_matrix = confusion_matrix(result['GT'].to_numpy(),result['classify'].to_numpy())

# %%
import seaborn as sns
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot=labels, fmt="")

# %%
b = df_hdrunk['mse'].count()

# %%
b

# %%
6/9

# %%
df[df.mae >0.09].count()

# %%
df.count()

# %%
52/67
